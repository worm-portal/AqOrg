# %%
import AqOrg

# %%
input_name = "alcohol_demo.csv"
output_name = "alcohol_demo_out.csv"
csv_out_name = "alcohol_demo_est.csv"

# %%
aoe = AqOrg.AqOrganicEstimator()

# %%
aoe.test_group_match("hexane")
# Out:
# Warning in match_groups(): problem identifying SMARTS group (C#N)-(CH2)-(CH2)-(C#N) . Skipping this group from now on...
# {'Yo': 0,
#  'C-[CX4H3]': 2,
#  'C-[CX4H2]-C': 4,
#  'C-[CX4H1](-C)-C': 0,
#  'C-[CX4H0](-C)(-C)-C': 0,
#  'O-[CX4H2]-C': 0,
#  'C-[CX4H1](-C)[OH]': 0,
#  'C-[CX4H0](-C)(-C)[OH]': 0,
#  'C-[OX2H]': 0,
#  'C-[C](-C)=O': 0,
#  'C-[CH2]-C=O': 0,
#  'C-[CH](-C)-C=O': 0,
#  'C-[C](-C)(-C)-C=O': 0,
#  'C-[C](=O)-O-C': 0,
#  '[CH](=O)-OC': 0,
#  'O=C-O-[CX4H1](-C)-C': 0,
#  'C-O-[CX4H0](-C)(-C)-C': 0,
#  'S-[CH2]-C': 0,
#  'S-[CH](-C)-C': 0,
#  'S-[C](-C)(-C)-C': 0,
#  'C-[SX2H1]': 0,
#  'C-[SX2]-C': 0,
#  'S-[S]-C': 0,
#  'S-[S]-S': 0,
#  'C-[CX4H1](-O-C)-C': 0,
#  'C-[OX2]-C': 0,
#  'O-[CH2]-O': 0,
#  'O-[CH](-C)-O': 0,
#  '[O](-C[CH3])-C[CH2]': 0,
#  'O-[CH2]-[CH2]-O': 0,
#  'N#C-[CH2]-C': 0,
#  'N#C-[CH](-C)-C': 0,
#  'C-[CX2H0]#N': 0,
#  '[CH2](-[CH2]-[CH2]-C#N)-C#N': 0,
#  'C-[Br]': 0,
#  'formula': 'C6H14'}

# %%
aoe.set_groups(input_name, output_name)
# Out:
# Warning! The formula of methanol does not equal the the elemental composition of the matched groups! This could be because the structure of methanol is missing representative groups.
# Formula of methanol:
# {'C': 1.0, 'H': 4.0, 'O': 1.0}
# Total formula of group matches:
# {'H': 1.0, 'O': 1.0}
# Warning: unable to load font metrics from dir C:\Users\gmboy\Miniconda3\envs\my-rdkit-env\lib\site-packages\rdkit\sping\PIL\pilfonts

# %%
aoe.create_df_est(csv_out_name, ig_method="Joback")

# %%
aoe.df_est
# Out:
#                            Gh Gh_err      Hh Hh_err      Sh Sh_err  Cph  \
# compound
# methanol               -17.51   0.24  -40.63   0.52  -77.54   1.45    9
# ethanol                -13.02   0.32  -53.99   0.68  -137.4    3.8  209
# 1-propanol             -12.34   0.32  -57.51   0.69  -151.5    4.3  271
