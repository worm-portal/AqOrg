# %%
from AqOrg import Estimate

# %%
b_carotene = Estimate("beta-carotene",
         smiles="CC(/C=C/C1=C(C)CCCC1(C)C)=C\C=C\C(C)=C\C=C\C=C(C)\C=C\C=C(C)\C=C\C2=C(C)CCCC2(C)C",
         #group_data="group_contribution_data_rings.csv",
        ).OBIGT

b_carotene
# Out:
#             name   abbrv formula state   ref1    ref2                 date  \
# 0  beta-carotene  C40H56  C40H56    aq  AqOrg  GrpAdd  17/04/2025 12:47:30
#
#   E_units          G         H  ...  Cp   V  a1.a  a2.b  a3.c  a4.d  c1.e  \
# 0       J  1021440.0  202740.0  ... NaN NaN   NaN   NaN   NaN   NaN   NaN
#
#        c2.f  omega.lambda  z.T
# 0  11.56858     -0.561854    0
#
# [1 rows x 21 columns]

# %%
b_carotene = Estimate("bacteriohopanetetrol",
                      #group_data="group_contribution_data_rings.csv",
                     ).OBIGT

b_carotene
# Out:
#                    name     abbrv   formula state   ref1    ref2  \
# 0  bacteriohopanetetrol  C35H62O4  C35H62O4    aq  AqOrg  GrpAdd
#
#                   date E_units         G          H  ...  Cp   V  a1.a  a2.b  \
# 0  17/04/2025 12:47:31       J -230260.0 -1365680.0  ... NaN NaN   NaN   NaN
#
#    a3.c  a4.d  c1.e      c2.f  omega.lambda  z.T
# 0   NaN   NaN   NaN -48.37931      0.734313    0
#
# [1 rows x 21 columns]
