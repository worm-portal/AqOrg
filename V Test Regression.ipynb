# %% [markdown]
# ### Aqueous Organic Estimator Supplementary Notebook

# %%
import pandas as pd
import numpy as np
import sys
from math import floor, log10 # for significant figure rounding
import statsmodels.api as sm # for multilinear regression
from string import ascii_lowercase
import itertools
import copy
from statsmodels.formula.api import ols
import keyword

# %% [markdown]
# ### Run only one of these three groups at a time

# %%
### ESTIMATE A NEW MATERIAL POINT
# save_as = 'all_new_new' 
# fixed_material_point = False 
# estimate_material_point = True 

### USE OLD MATERIAL POINT
# save_as = 'all_new_old' 
# fixed_material_point = True 

### DO NOT USE OR ESTIMATE A MATERIAL POINT
save_as = 'fixed'
fixed_material_point = True 
estimate_material_point = False

# %%
# -*- coding: utf-8 -*-
"""
Created on Tue Nov 27 09:36:15 2018
Modified on Mar 21, 2019 by Grayson

@author: Vincent
@author: Grayson
"""
file_name = 'primary_compiled_11-30-22_out.csv' #new groups
props = ['dGh','dHh','Vh','Cph'] #properties you are wanting to regress

material_point_dict = {"dGh":7.95,"dHh":-2.29, "Cph":0, "Vh":1.12} # material point value. Valid only if fixed_material_point = True. Values taken from Plyasunov and Shock 2000.

sig_figs = 3
# =============================================================================
#                                     MAIN
# =============================================================================
def main():
    for prop in props:
        if fixed_material_point:
            material_point = material_point_dict[prop]
        else:
            material_point = 0
        group_property_estimator(file_name, prop, sig_figs, material_point, estimate_material_point)
    
    
# =============================================================================
#                                  FUNCTIONS
# =============================================================================
round_to_n = lambda x, n: round(x, -int(floor(log10(abs(x)))) + (n - 1))

def iter_all_strings():
    for size in itertools.count(1):
        for s in itertools.product(ascii_lowercase, repeat=size):
            yield "".join(s)

def group_property_estimator(file_name, dependent_param, sf, material_point, estimate_material_point):   
    df_data = pd.read_csv(file_name)
    
    # remove rows containing only NA
#     df_data = df_data[np.isfinite(df_data[df_data.columns.values[len(df_data.columns.values)-1]])]
    
    # remove columns containing 0 groups
    df_data = df_data.loc[:, (df_data != 0).any(axis=0)]

    # get data subset that needs a prediction
    df_topred = df_data[np.isfinite(df_data[dependent_param]) == False]
    
    # get data subset that does not need a prediction
    df_not_topred = df_data[np.isfinite(df_data[dependent_param]) == True]
    
    # delete rows representing compounds that need a prediction when they contain a group that is not
    # represented in the training set.
    delrows = []
    for col in df_not_topred.columns.values:
        try:
            if sum(df_not_topred[col]) == 0:
                for row in df_topred.index.values:
                    if df_topred.loc[row, col] != 0:
                        delrows.append(row)
        except:
            pass
    bad_df = df_topred.index.isin(delrows)
    df_topred = df_topred[~bad_df]
    
    # remove rows without y values
    df_data = df_data[np.isfinite(df_data[dependent_param])]
    
    ## define the independent parameter
    X = df_data[[x for x in list(df_data.columns.values) if not x in ["compound", "formula", dependent_param]+props]]
    
    ## define the dependent parameter
    y = df_data[dependent_param]
    
    # get X of molecules to predict
    X_topred = df_topred[[x for x in list(df_topred.columns.values) if not x in ["compound", "formula", dependent_param]+props]]
    
    if not fixed_material_point:
        
        ## add an intercept to the multi reg
        if estimate_material_point:
            X["material point"] = 1
            X_topred["material point"] = 1
            
        multi_reg = sm.OLS(y[0:], X[0:]).fit() # perform the multiple regression
        prediction = multi_reg.predict(X) # make the predictions from the multi_reg
        preds = multi_reg.predict(X_topred)
        
        # set these variables to 0 regardless of whether material point is being estimated
        material_point = 0 
        material_point_err = 0
        
    else:
        
        # subtract material point from y values (dependent params)
        df_data["y_minus_Yo"] = df_data[dependent_param] - material_point
        
        # ols formulas can't handle SMARTS strings as variables,
        # so store them in a dictionary of simpler strings (generated iteratively)
        # in the form {label:SMARTS}
        label_dict = {}
        X_vars = list(X.columns.values)
        for i,s in enumerate(itertools.islice(iter_all_strings(), len(X_vars))):
            if s in keyword.kwlist: # ols cannot handle formulas containing python keywords like "as" or "in"
                s = s + "1"
            label_dict[s] = X_vars[i]
        
        # create an inverse label dictionary {SMARTS:label}
        inv_label_dict = {v: k for k, v in label_dict.items()}
        
        # rename dependent variable columns with new labels
        X = X.rename(columns=inv_label_dict)
        X_topred = X_topred.rename(columns=inv_label_dict)
        df_data = df_data.rename(columns=inv_label_dict)
        
        formula_str = "y_minus_Yo ~ " + " + ".join(list(X.columns.values)) + " -1"
        
        multi_reg = ols(formula=formula_str, data=df_data).fit()
        prediction = multi_reg.predict(X) # make the predictions from the multi_reg
        preds = multi_reg.predict(X_topred)
        
        # restore dependent variable column names
        X = X.rename(columns=label_dict)
        X_topred = X_topred.rename(columns=label_dict)
        df_data = df_data.rename(columns=label_dict)
        
#     print(multi_reg.summary()) # print out the statistics
#     print(multi_reg.params) 
#     print(multi_reg.params.values) # print param as an array

    group_property_dict = dict(zip(X.columns.values, [round(val, 4) for val in multi_reg.params.values]))

    group_property_se_dict = dict(zip(X.columns.values, [round(val, 4) for val in multi_reg.bse.values]))
    
    if fixed_material_point:
        group_property_dict["material_point"] = material_point
        group_property_se_dict["material_point"] = 0 # material point uncertainty fixed at 0 (see Plyasunov and Shock 2000)

        
    pred_errs = [sum([n_group*group_property_se_dict[group]**2 for n_group, group in zip(X.loc[idx], X.columns.values)])**0.5 for idx in X.index]

    topred_errs = [sum([n_group*group_property_se_dict[group]**2 for n_group, group in zip(X_topred.loc[idx], X_topred.columns.values)])**0.5 for idx in X_topred.index]
    
    
    
    comp_pred_df = pd.DataFrame({"compound":list(df_data["compound"]),
                                 "actual":df_data[dependent_param],
                                 "prediction":[round(pred+material_point, 2) for pred in prediction.values],
                                 "pred errs":[round(err, 2) for err in pred_errs]})
    

    df_preds = pd.DataFrame({"compound":list(df_topred["compound"]),
                                "actual":df_topred[dependent_param],
                                 "prediction":[round(pred+material_point, 2) for pred in preds.values],
                                 "pred errs":[round(err, 2) for err in topred_errs]})
    
    df_final = comp_pred_df.append(pd.DataFrame(data = df_preds))

    
    with pd.option_context('display.max_rows', None, 'display.max_columns', None):
        print("\nPredicted group contributions for " + dependent_param + ":")
        df_group_property = pd.DataFrame(group_property_dict.items(), columns=['group', 'value'])
        print(df_group_property)
        print("\nPredicted standard error of group contributions for " + dependent_param + ":")
        df_group_se = pd.DataFrame(group_property_se_dict.items(), columns=['group', 'std err'])
        print(df_group_se)
        print("\nPredictions for " + dependent_param + ":")
        print(df_final.to_string(index=False))
    
    if save_as != None:
        df_final.to_csv(save_as+"_"+dependent_param+".csv", index=False)
        df_group_property.to_csv(save_as+"_"+dependent_param+"_group_property.csv", index=False) #reports 0s when not able to estimate
        df_group_se.to_csv(save_as+"_"+dependent_param+"_group_se.csv", index=False)
        


    
# =============================================================================
#                                CALL MAIN
# =============================================================================
if __name__=='__main__':
    main()
# Out:
# Predicted group contributions for dGh:
#                           group    value
# 0                C-[CH2R1!r3]-C   0.7962
# 1             C-[CHR1!r3](-C)-C  -1.3466
# 2      C-[CX4H0R1!r3](-C)(-C)-C  -1.6542
# 3              C=[CX3H1R1!r3]-C  -0.7999
# 4          C=[CX3H0R1!r3](-C)-C  -4.7447
# 5                   C-[CH2R2]-C  -1.4519
# 6                C-[CHR2](-C)-C  -0.8086
# 7         C-[CX4H0R2](-C)(-C)-C  -0.7851
# 8                 C=[CX3H1R2]-C  -2.6639
# 9             C=[CX3H0R2](-C)-C  -2.1083
# 10               C-[CHR3](-C)-C  -0.2867
# 11        C-[CX4H0R3](-C)(-C)-C   1.3100
# 12             [CX3H2R0]=[C!H2]   2.3545
# 13                C=[CX3H1R0]-C  -0.8882
# 14            C=[CX3H0R0](-C)-C  -5.0424
# 15                [CHR0]#[CHR0]  -0.1492
# 16                  C#[CX2H1R0]   0.1149
# 17                C-[CX2H0R0]#C  -4.2584
# 18                  C#[NX1H0R0]  -9.8886
# 19                C-[CX2H0R0]#N  -9.8886
# 20              [CH3R0]-[CH3R0]   7.6000
# 21             [C!H3]-[CX4H3R0]   3.3230
# 22                C-[CX4H2R0]-C   0.6715
# 23            C-[CX4H1R0](-C)-C  -1.2928
# 24        C-[CX4H0R0](-C)(-C)-C  -2.9700
# 25                  O-[CX4H3R0]  -1.5846
# 26                O-[CX4H2R0]-C  -4.2657
# 27            O-[CX4H1R0](-C)-C  -6.7429
# 28        O-[CX4H0R0](-C)(-C)-C -10.1859
# 29                   C-[OX2HR0] -19.8853
# 30                  C-[OX2R0]-C  -5.4873
# 31                  O-[CH2R0]-O   1.2302
# 32               O-[CHR0](-C)-O  -3.6780
# 33                  C-[SX2H1R0]  -4.0372
# 34                  C-[SX2R0]-C  -5.1446
# 35                    S-[CH3R0]  -0.7689
# 36                  S-[CH2R0]-C  -3.8463
# 37               S-[CHR0](-C)-C  -6.4930
# 38            S-[CR0](-C)(-C)-C  -6.1918
# 39                    S-[SR0]-C  -2.9736
# 40                    S-[SR0]-S  -1.7124
# 41                        C=[O]  -8.9518
# 42                O=[CX3H1R0]-O   4.4017
# 43              O=[CX3R0](-C)-O  -0.2073
# 44                C-[CR0](-C)=O -13.1462
# 45                        C=[S]  -0.3408
# 46                      S=[C]=S  -0.1704
# 47                   c[cX3H+0]c  -0.6019
# 48                    c-[CX4H3]   3.2249
# 49                  c[cX3](-C)c  -3.7245
# 50                  c-[CX4H2]-C   0.5722
# 51              c-[CX4H1](-C)-C  -2.1016
# 52          c-[CX4H0](-C)(-C)-C  -4.9498
# 53                   C=[CX3H1]c  -0.4703
# 54          [CX3H2R0]=[CX3H2R0]   5.2900
# 55          [CH2]1-[CH2]-[CH2]1   3.1500
# 56  [CH2R1]1-[CH2R1]-[CH1R1]1-C  -0.0000
# 57    [CH0R2]1-[CH2R1]-[CH1R2]1   0.0132
# 58           C-[CH1R1!r3](-C)-O  -7.3796
# 59               material_point   7.9500
#
# Predicted standard error of group contributions for dGh:
#                           group  std err
# 0                C-[CH2R1!r3]-C   0.0356
# 1             C-[CHR1!r3](-C)-C   0.2971
# 2      C-[CX4H0R1!r3](-C)(-C)-C   0.9506
# 3              C=[CX3H1R1!r3]-C   0.0886
# 4          C=[CX3H0R1!r3](-C)-C   0.2680
# 5                   C-[CH2R2]-C   0.3569
# 6                C-[CHR2](-C)-C   0.6308
# 7         C-[CX4H0R2](-C)(-C)-C   0.5274
# 8                 C=[CX3H1R2]-C   0.5362
# 9             C=[CX3H0R2](-C)-C   0.3926
# 10               C-[CHR3](-C)-C   0.4470
# 11        C-[CX4H0R3](-C)(-C)-C   0.3958
# 12             [CX3H2R0]=[C!H2]   0.2365
# 13                C=[CX3H1R0]-C   0.2230
# 14            C=[CX3H0R0](-C)-C   0.2688
# 15                [CHR0]#[CHR0]   0.5208
# 16                  C#[CX2H1R0]   0.3945
# 17                C-[CX2H0R0]#C   0.2739
# 18                  C#[NX1H0R0]   0.0804
# 19                C-[CX2H0R0]#N   0.0804
# 20              [CH3R0]-[CH3R0]   1.2717
# 21             [C!H3]-[CX4H3R0]   0.0650
# 22                C-[CX4H2R0]-C   0.0187
# 23            C-[CX4H1R0](-C)-C   0.1303
# 24        C-[CX4H0R0](-C)(-C)-C   0.3137
# 25                  O-[CX4H3R0]   0.1442
# 26                O-[CX4H2R0]-C   0.1119
# 27            O-[CX4H1R0](-C)-C   0.1554
# 28        O-[CX4H0R0](-C)(-C)-C   0.2296
# 29                   C-[OX2HR0]   0.1202
# 30                  C-[OX2R0]-C   0.1938
# 31                  O-[CH2R0]-O   0.4433
# 32               O-[CHR0](-C)-O   0.5244
# 33                  C-[SX2H1R0]   0.2327
# 34                  C-[SX2R0]-C   0.3466
# 35                    S-[CH3R0]   0.1894
# 36                  S-[CH2R0]-C   0.2125
# 37               S-[CHR0](-C)-C   0.5374
# 38            S-[CR0](-C)(-C)-C   1.1721
# 39                    S-[SR0]-C   0.2278
# 40                    S-[SR0]-S   0.7321
# 41                        C=[O]   0.0807
# 42                O=[CX3H1R0]-O   0.1698
# 43              O=[CX3R0](-C)-O   0.0968
# 44                C-[CR0](-C)=O   0.1267
# 45                        C=[S]   0.1609
# 46                      S=[C]=S   0.0804
# 47                   c[cX3H+0]c   0.0197
# 48                    c-[CX4H3]   0.2814
# 49                  c[cX3](-C)c   0.2841
# 50                  c-[CX4H2]-C   0.2938
# 51              c-[CX4H1](-C)-C   0.3607
# 52          c-[CX4H0](-C)(-C)-C   0.7926
# 53                   C=[CX3H1]c   1.0903
# 54          [CX3H2R0]=[CX3H2R0]   1.2717
# 55          [CH2]1-[CH2]-[CH2]1   0.4239
# 56  [CH2R1]1-[CH2R1]-[CH1R1]1-C   0.0000
# 57    [CH0R2]1-[CH2R1]-[CH1R2]1   0.5315
# 58           C-[CH1R1!r3](-C)-O   0.3518
# 59               material_point   0.0000
#
# Predictions for dGh:
#                          compound  actual  prediction  pred errs
#                            Ethane   15.55       15.55       1.27
#                           Propane   16.09       15.27       0.09
#                          n-Butane   16.58       15.94       0.10
#                         n-Pentane   17.36       16.61       0.10
#                         n-Pentane   17.27       16.61       0.10
#                         n-Pentane   17.60       16.61       0.10
#                         n-Pentane   18.44       16.61       0.10
#                         n-Pentane   17.67       16.61       0.10
#                         n-Pentane   17.60       16.61       0.10
#                         n-Pentane   17.60       16.61       0.10
#                         n-Pentane   17.76       16.61       0.10
#                         n-Pentane   17.29       16.61       0.10
#                         n-Pentane   15.16       16.61       0.10
#                         n-Pentane   19.65       16.61       0.10
#                         n-Pentane   17.70       16.61       0.10
#                         n-Pentane   17.84       16.61       0.10
#                         n-Pentane   17.18       16.61       0.10
#                         n-Pentane   14.67       16.61       0.10
#                          n-Hexane   18.61       17.28       0.10
#                          n-Hexane   17.88       17.28       0.10
#                          n-Hexane   18.30       17.28       0.10
#                          n-Hexane   16.47       17.28       0.10
#                          n-Hexane   18.07       17.28       0.10
#                          n-Hexane   19.00       17.28       0.10
#                          n-Hexane   18.48       17.28       0.10
#                          n-Hexane   17.91       17.28       0.10
#                          n-Hexane   16.12       17.28       0.10
#                          n-Hexane   18.46       17.28       0.10
#                          n-Hexane   17.91       17.28       0.10
#                          n-Hexane   11.58       17.28       0.10
#                          n-Hexane   18.59       17.28       0.10
#                          n-Hexane   17.92       17.28       0.10
#                          n-Hexane   17.94       17.28       0.10
#                          n-Hexane   17.66       17.28       0.10
#                          n-Hexane   16.95       17.28       0.10
#                          n-Hexane   18.59       17.28       0.10
#                          n-Hexane   17.23       17.28       0.10
#                          n-Hexane   12.30       17.28       0.10
#                          n-Hexane   15.26       17.28       0.10
#                          n-Hexane   11.95       17.28       0.10
#                         n-Heptane   19.65       17.95       0.10
#                         n-Heptane   18.62       17.95       0.10
#                         n-Heptane   18.99       17.95       0.10
#                         n-Heptane   19.45       17.95       0.10
#                         n-Heptane   18.47       17.95       0.10
#                         n-Heptane   19.32       17.95       0.10
#                         n-Heptane   18.93       17.95       0.10
#                         n-Heptane   18.39       17.95       0.10
#                         n-Heptane   19.63       17.95       0.10
#                         n-Heptane   17.97       17.95       0.10
#                         n-Heptane   19.08       17.95       0.10
#                         n-Heptane   19.14       17.95       0.10
#                         n-Heptane   19.21       17.95       0.10
#                         n-Heptane   18.97       17.95       0.10
#                         n-Heptane   15.92       17.95       0.10
#                         n-Heptane   11.93       17.95       0.10
#                          n-Octane   20.04       18.62       0.10
#                          n-Octane   19.42       18.62       0.10
#                          n-Octane   20.91       18.62       0.10
#                          n-Octane   19.84       18.62       0.10
#                          n-Octane   14.46       18.62       0.10
#                          n-Octane   19.60       18.62       0.10
#                          n-Octane   19.21       18.62       0.10
#                          n-Octane   11.52       18.62       0.10
#                          n-Octane   19.20       18.62       0.10
#                          n-Octane   19.85       18.62       0.10
#                          n-Octane   18.76       18.62       0.10
#                          n-Octane   20.16       18.62       0.10
#                          n-Octane   21.10       18.62       0.10
#                          n-Octane   18.44       18.62       0.10
#                          n-Octane   19.41       18.62       0.10
#                          n-Octane   19.91       18.62       0.10
#                          n-Octane   19.30       18.62       0.10
#                          n-Octane   20.03       18.62       0.10
#                          n-Octane   11.52       18.62       0.10
#                          n-Nonane   20.78       19.30       0.10
#                          n-Nonane   21.16       19.30       0.10
#                          n-Nonane   14.94       19.30       0.10
#                          n-Nonane   20.99       19.30       0.10
#                          n-Nonane   21.61       19.30       0.10
#                          n-Nonane   22.93       19.30       0.10
#                          n-Nonane   20.14       19.30       0.10
#                          n-Decane   21.42       19.97       0.11
#                          n-Decane   21.26       19.97       0.11
#                          n-Decane   25.55       19.97       0.11
#                          n-Decane   21.12       19.97       0.11
#                          n-Decane   23.49       19.97       0.11
#                          n-Decane   24.09       19.97       0.11
#                        n-Undecane   22.82       20.64       0.11
#                        n-Undecane   25.11       20.64       0.11
#                        n-Undecane   24.62       20.64       0.11
#                        n-Dodecane   25.65       21.31       0.11
#                        n-Dodecane   22.56       21.31       0.11
#                        n-Dodecane   24.11       21.31       0.11
#                        n-Dodecane   22.39       21.31       0.11
#                        n-Dodecane   20.40       21.31       0.11
#                       n-Tridecane   25.28       21.98       0.11
#                     n-Tetradecane   23.17       22.65       0.11
#                   2-Methylpropane   17.32       16.63       0.17
#               2,2-Dimethylpropane   18.40       18.27       0.34
#                    2-Methylbutane   17.60       17.30       0.17
#                    2-Methylbutane   17.89       17.30       0.17
#                    2-Methylbutane   18.03       17.30       0.17
#                    2-Methylbutane   17.95       17.30       0.17
#                    2-Methylbutane   17.93       17.30       0.17
#                    2-Methylbutane   18.04       17.30       0.17
#                2,2-Dimethylbutane   18.54       18.94       0.34
#                2,2-Dimethylbutane   18.26       18.94       0.34
#                2,2-Dimethylbutane   18.89       18.94       0.34
#                2,3-Dimethylbutane   18.03       18.66       0.23
#                2,3-Dimethylbutane   17.62       18.66       0.23
#                   2-Methylpentane   16.65       17.97       0.17
#                   2-Methylpentane   18.74       17.97       0.17
#                   2-Methylpentane   18.26       17.97       0.17
#                   2-Methylpentane   18.50       17.97       0.17
#                   2-Methylpentane   18.58       17.97       0.17
#                   3-Methylpentane   18.41       17.97       0.17
#                   3-Methylpentane   18.43       17.97       0.17
#                   3-Methylpentane   17.66       17.97       0.17
#                   3-Methylpentane   18.48       17.97       0.17
#               2,2-Dimethylpentane   20.04       19.61       0.34
#                          1-Nonyne   11.23       11.16       0.49
#          2,2,5-Trimethyl-3-hexyne   12.44       11.79       0.54
#      2,2,5,5-Tetramethyl-3-hexyne   13.59       13.43       0.61
#                           Benzene    4.25        4.34       0.05
#                           Benzene    4.26        4.34       0.05
#                           Benzene    3.62        4.34       0.05
#                           Benzene    4.24        4.34       0.05
#                           Benzene    4.07        4.34       0.05
#                           Benzene    4.39        4.34       0.05
#                           Benzene    4.29        4.34       0.05
#                           Benzene    4.25        4.34       0.05
#                           Benzene    4.27        4.34       0.05
#                           Benzene    4.36        4.34       0.05
#                           Benzene    4.51        4.34       0.05
#                           Benzene    4.27        4.34       0.05
#                           Benzene    4.35        4.34       0.05
#                           Benzene    4.28        4.34       0.05
#                           Benzene    4.16        4.34       0.05
#                           Benzene    4.54        4.34       0.05
#                           Benzene    4.59        4.34       0.05
#                           Benzene    4.24        4.34       0.05
#                           Benzene    3.86        4.34       0.05
#                           Benzene    4.49        4.34       0.05
#                           Benzene    4.14        4.34       0.05
#                           Benzene    4.30        4.34       0.05
#                           Benzene    4.18        4.34       0.05
#                           Benzene    4.15        4.34       0.05
#                           Benzene    4.46        4.34       0.05
#                           Benzene    4.28        4.34       0.05
#                           Benzene    4.33        4.34       0.05
#                           Benzene    4.41        4.34       0.05
#                           Benzene    4.27        4.34       0.05
#                           Benzene    4.31        4.34       0.05
#                           Benzene    4.38        4.34       0.05
#                           Benzene    3.44        4.34       0.05
#                           Benzene    4.34        4.34       0.05
#                           Benzene    3.84        4.34       0.05
#                           Benzene    4.35        4.34       0.05
#                           Benzene    4.04        4.34       0.05
#                           Benzene    4.45        4.34       0.05
#                           Benzene    4.21        4.34       0.05
#                           Benzene    4.20        4.34       0.05
#                           Benzene    4.76        4.34       0.05
#                           Benzene    4.48        4.34       0.05
#                           Benzene    4.28        4.34       0.05
#                           Benzene    4.28        4.34       0.05
#                           Benzene    4.20        4.34       0.05
#                           Benzene    4.10        4.34       0.05
#                           Benzene    4.08        4.34       0.05
#                           Benzene    4.16        4.34       0.05
#                           Benzene    4.26        4.34       0.05
#                           Benzene    4.21        4.34       0.05
#                           Benzene    4.24        4.34       0.05
#                           Benzene    4.22        4.34       0.05
#                           Benzene    4.21        4.34       0.05
#                           Benzene    4.28        4.34       0.05
#                           Benzene    6.06        4.34       0.05
#                           Benzene    3.98        4.34       0.05
#                           Benzene    4.28        4.34       0.05
#                           Benzene    4.18        4.34       0.05
#                           Benzene    4.23        4.34       0.05
#                           Benzene    5.66        4.34       0.05
#                           Benzene    4.01        4.34       0.05
#                           Benzene    4.70        4.34       0.05
#                           Benzene    4.26        4.34       0.05
#                           Benzene    4.24        4.34       0.05
#                           Benzene    4.15        4.34       0.05
#                           Benzene    3.83        4.34       0.05
#                           Benzene    4.34        4.34       0.05
#                           Benzene    5.48        4.34       0.05
#                           Benzene    3.73        4.34       0.05
#                           Benzene    4.31        4.34       0.05
#                           Benzene    4.23        4.34       0.05
#                           Benzene    4.30        4.34       0.05
#                           Benzene    4.19        4.34       0.05
#                           Benzene    4.29        4.34       0.05
#                           Benzene    4.28        4.34       0.05
#                           Benzene    4.19        4.34       0.05
#                           Benzene    4.31        4.34       0.05
#                           Benzene    4.23        4.34       0.05
#                           Benzene    4.17        4.34       0.05
#                           Benzene    4.65        4.34       0.05
#                           Benzene    4.21        4.34       0.05
#                           Benzene    4.10        4.34       0.05
#                           Benzene    4.28        4.34       0.05
#                           Benzene    4.12        4.34       0.05
#                           Benzene    4.13        4.34       0.05
#                     Methylbenzene    5.20        4.44       0.40
#                     Methylbenzene    4.38        4.44       0.40
#                     Methylbenzene    4.62        4.44       0.40
#                     Methylbenzene    4.53        4.44       0.40
#                     Methylbenzene    4.53        4.44       0.40
#                     Methylbenzene    4.39        4.44       0.40
#                     Methylbenzene    5.60        4.44       0.40
#                     Methylbenzene    4.80        4.44       0.40
#                     Methylbenzene    4.58        4.44       0.40
#                     Methylbenzene    4.48        4.44       0.40
#                     Methylbenzene    4.59        4.44       0.40
#                     Methylbenzene    4.69        4.44       0.40
#                     Methylbenzene    4.80        4.44       0.40
#                     Methylbenzene    5.07        4.44       0.40
#                     Methylbenzene    4.45        4.44       0.40
#                     Methylbenzene    4.97        4.44       0.40
#                     Methylbenzene    4.73        4.44       0.40
#                     Methylbenzene    4.24        4.44       0.40
#                     Methylbenzene    4.72        4.44       0.40
#                     Methylbenzene    4.98        4.44       0.40
#                     Methylbenzene    4.42        4.44       0.40
#                     Methylbenzene    4.62        4.44       0.40
#                     Methylbenzene    4.64        4.44       0.40
#                     Methylbenzene    4.55        4.44       0.40
#                     Methylbenzene    4.54        4.44       0.40
#                     Methylbenzene    5.10        4.44       0.40
#                     Methylbenzene    3.64        4.44       0.40
#                     Methylbenzene    4.61        4.44       0.40
#                     Methylbenzene    4.93        4.44       0.40
#                     Methylbenzene    4.11        4.44       0.40
#                     Methylbenzene    2.95        4.44       0.40
#                     Methylbenzene    4.43        4.44       0.40
#                     Methylbenzene    4.61        4.44       0.40
#                     Methylbenzene    4.33        4.44       0.40
#                     Methylbenzene    4.70        4.44       0.40
#                     Methylbenzene    4.25        4.44       0.40
#                     Methylbenzene    4.36        4.44       0.40
#                     Methylbenzene    4.70        4.44       0.40
#                     Methylbenzene    4.99        4.44       0.40
#                     Methylbenzene    4.68        4.44       0.40
#                     Methylbenzene    4.31        4.44       0.40
#                     Methylbenzene    3.27        4.44       0.40
#                     Methylbenzene    4.43        4.44       0.40
#                     Methylbenzene    4.73        4.44       0.40
#                     Methylbenzene    4.47        4.44       0.40
#                     Methylbenzene    4.53        4.44       0.40
#                     Methylbenzene    4.77        4.44       0.40
#                     Methylbenzene    3.70        4.44       0.40
#                     Methylbenzene    4.24        4.44       0.40
#                     Methylbenzene    4.28        4.44       0.40
#                     Methylbenzene    2.00        4.44       0.40
#                     Methylbenzene    4.72        4.44       0.40
#                     Methylbenzene    4.55        4.44       0.40
#                     Methylbenzene    4.13        4.44       0.40
#                     Methylbenzene    4.55        4.44       0.40
#                     Methylbenzene    4.64        4.44       0.40
#                     Methylbenzene    4.86        4.44       0.40
#                     Methylbenzene    4.70        4.44       0.40
#                     Methylbenzene    6.77        4.44       0.40
#                     Methylbenzene    4.23        4.44       0.40
#                     Methylbenzene    4.98        4.44       0.40
#                     Methylbenzene    4.47        4.44       0.40
#                     Methylbenzene    4.57        4.44       0.40
#                     Methylbenzene    4.23        4.44       0.40
#                     Methylbenzene    4.72        4.44       0.40
#                     Methylbenzene    4.34        4.44       0.40
#                     Methylbenzene    5.00        4.44       0.40
#                     Methylbenzene    4.40        4.44       0.40
#                     Methylbenzene    4.73        4.44       0.40
#                     Methylbenzene    4.63        4.44       0.40
#                     Methylbenzene    4.24        4.44       0.40
#                     Methylbenzene    4.79        4.44       0.40
#                     Methylbenzene    4.66        4.44       0.40
#                     Methylbenzene    4.82        4.44       0.40
#                     Methylbenzene    4.02        4.44       0.40
#               1,2-Dimethylbenzene    3.44        4.54       0.57
#               1,2-Dimethylbenzene    4.15        4.54       0.57
#               1,2-Dimethylbenzene    3.81        4.54       0.57
#               1,2-Dimethylbenzene    3.70        4.54       0.57
#               1,2-Dimethylbenzene    4.92        4.54       0.57
#               1,2-Dimethylbenzene    3.60        4.54       0.57
#               1,2-Dimethylbenzene    4.01        4.54       0.57
#               1,2-Dimethylbenzene    4.16        4.54       0.57
#               1,2-Dimethylbenzene    3.64        4.54       0.57
#               1,2-Dimethylbenzene    3.92        4.54       0.57
#               1,2-Dimethylbenzene    3.92        4.54       0.57
#               1,2-Dimethylbenzene    4.19        4.54       0.57
#               1,2-Dimethylbenzene    3.65        4.54       0.57
#               1,2-Dimethylbenzene    4.20        4.54       0.57
#               1,2-Dimethylbenzene    4.36        4.54       0.57
#               1,2-Dimethylbenzene    4.36        4.54       0.57
#               1,2-Dimethylbenzene    4.30        4.54       0.57
#               1,2-Dimethylbenzene    3.62        4.54       0.57
#               1,2-Dimethylbenzene    2.96        4.54       0.57
#               1,2-Dimethylbenzene    4.23        4.54       0.57
#               1,2-Dimethylbenzene    4.24        4.54       0.57
#               1,2-Dimethylbenzene    3.86        4.54       0.57
#               1,3-Dimethylbenzene    5.33        4.54       0.57
#               1,3-Dimethylbenzene    4.70        4.54       0.57
#               1,3-Dimethylbenzene    4.72        4.54       0.57
#               1,3-Dimethylbenzene    4.68        4.54       0.57
#               1,3-Dimethylbenzene    4.51        4.54       0.57
#               1,3-Dimethylbenzene    4.86        4.54       0.57
#               1,3-Dimethylbenzene    4.63        4.54       0.57
#               1,3-Dimethylbenzene    5.03        4.54       0.57
#               1,3-Dimethylbenzene    4.76        4.54       0.57
#               1,3-Dimethylbenzene    4.94        4.54       0.57
#               1,3-Dimethylbenzene    4.97        4.54       0.57
#               1,3-Dimethylbenzene    5.19        4.54       0.57
#               1,3-Dimethylbenzene    4.88        4.54       0.57
#               1,3-Dimethylbenzene    4.98        4.54       0.57
#               1,3-Dimethylbenzene    5.32        4.54       0.57
#               1,3-Dimethylbenzene    5.32        4.54       0.57
#               1,3-Dimethylbenzene    4.66        4.54       0.57
#               1,3-Dimethylbenzene    5.10        4.54       0.57
#               1,3-Dimethylbenzene    4.25        4.54       0.57
#               1,3-Dimethylbenzene    4.84        4.54       0.57
#               1,3-Dimethylbenzene    4.92        4.54       0.57
#               1,3-Dimethylbenzene    4.91        4.54       0.57
#               1,3-Dimethylbenzene    4.37        4.54       0.57
#               1,3-Dimethylbenzene    4.69        4.54       0.57
#               1,4-Dimethylbenzene    4.70        4.54       0.57
#               1,4-Dimethylbenzene    4.98        4.54       0.57
#               1,4-Dimethylbenzene    4.75        4.54       0.57
#               1,4-Dimethylbenzene    5.57        4.54       0.57
#               1,4-Dimethylbenzene    4.95        4.54       0.57
#               1,4-Dimethylbenzene    4.34        4.54       0.57
#               1,4-Dimethylbenzene    4.49        4.54       0.57
#               1,4-Dimethylbenzene    4.83        4.54       0.57
#               1,4-Dimethylbenzene    5.15        4.54       0.57
#               1,4-Dimethylbenzene    5.04        4.54       0.57
#               1,4-Dimethylbenzene    4.88        4.54       0.57
#               1,4-Dimethylbenzene    5.25        4.54       0.57
#               1,4-Dimethylbenzene    2.92        4.54       0.57
#               1,4-Dimethylbenzene    4.97        4.54       0.57
#               1,4-Dimethylbenzene    5.07        4.54       0.57
#               1,4-Dimethylbenzene    4.33        4.54       0.57
#               1,4-Dimethylbenzene    5.09        4.54       0.57
#               1,4-Dimethylbenzene    5.11        4.54       0.57
#               1,4-Dimethylbenzene    5.11        4.54       0.57
#               1,4-Dimethylbenzene    5.13        4.54       0.57
#               1,4-Dimethylbenzene    4.70        4.54       0.57
#               1,4-Dimethylbenzene    5.02        4.54       0.57
#               1,4-Dimethylbenzene    3.59        4.54       0.57
#               1,4-Dimethylbenzene    4.96        4.54       0.57
#               1,4-Dimethylbenzene    4.49        4.54       0.57
#               1,4-Dimethylbenzene    4.52        4.54       0.57
#                      Ethylbenzene    5.13        5.11       0.42
#                      Ethylbenzene    5.12        5.11       0.42
#                      Ethylbenzene    4.81        5.11       0.42
#                      Ethylbenzene    5.19        5.11       0.42
#                      Ethylbenzene    5.43        5.11       0.42
#                      Ethylbenzene    4.71        5.11       0.42
#                      Ethylbenzene    5.12        5.11       0.42
#                      Ethylbenzene    5.33        5.11       0.42
#                      Ethylbenzene    5.08        5.11       0.42
#                      Ethylbenzene    5.10        5.11       0.42
#                      Ethylbenzene    4.99        5.11       0.42
#                      Ethylbenzene    5.04        5.11       0.42
#                      Ethylbenzene    5.04        5.11       0.42
#                      Ethylbenzene    5.47        5.11       0.42
#                      Ethylbenzene    4.39        5.11       0.42
#                      Ethylbenzene    5.12        5.11       0.42
#            1,3,5-Trimethylbenzene    4.39        4.65       0.69
#            1,3,5-Trimethylbenzene    4.61        4.65       0.69
#            1,3,5-Trimethylbenzene    4.81        4.65       0.69
#            1,3,5-Trimethylbenzene    5.04        4.65       0.69
#            1,3,5-Trimethylbenzene    4.73        4.65       0.69
#            1,3,5-Trimethylbenzene    5.20        4.65       0.69
#            1,3,5-Trimethylbenzene    5.53        4.65       0.69
#            1,3,5-Trimethylbenzene    5.22        4.65       0.69
#            1,3,5-Trimethylbenzene    4.83        4.65       0.69
#            1,3,5-Trimethylbenzene    5.81        4.65       0.69
#            1,3,5-Trimethylbenzene    3.49        4.65       0.69
#           1-Ethyl-2-methylbenzene    4.25        5.21       0.58
#            1,2,3-Trimethylbenzene    3.31        4.65       0.69
#            1,2,3-Trimethylbenzene    3.35        4.65       0.69
#            1,2,3-Trimethylbenzene    2.97        4.65       0.69
#            1,2,4-Trimethylbenzene    4.59        4.65       0.69
#            1,2,4-Trimethylbenzene    4.42        4.65       0.69
#            1,2,4-Trimethylbenzene    4.63        4.65       0.69
#            1,2,4-Trimethylbenzene    4.63        4.65       0.69
#            1,2,4-Trimethylbenzene    4.31        4.65       0.69
#                            cumene    6.04        5.76       0.47
#                            cumene    5.97        5.76       0.47
#                            cumene    5.95        5.76       0.47
#                            cumene    4.26        5.76       0.47
#                            cumene    6.19        5.76       0.47
#                            cumene    6.79        5.76       0.47
#                            cumene    6.79        5.76       0.47
#                            cumene    6.04        5.76       0.47
#                            cumene    6.69        5.76       0.47
#                            cumene    6.70        5.76       0.47
#                            cumene    5.53        5.76       0.47
#                            cumene    4.52        5.76       0.47
#                   n-Propylbenzene    5.72        5.78       0.42
#                   n-Propylbenzene    6.04        5.78       0.42
#                   n-Propylbenzene    6.10        5.78       0.42
#                   n-Propylbenzene    6.08        5.78       0.42
#                   n-Propylbenzene    6.01        5.78       0.42
#                   n-Propylbenzene    5.95        5.78       0.42
#                   n-Propylbenzene    4.66        5.78       0.42
#                   n-Propylbenzene    5.90        5.78       0.42
#                   n-Propylbenzene    5.62        5.78       0.42
#                   n-Propylbenzene    5.95        5.78       0.42
#                   n-Propylbenzene    5.79        5.78       0.42
#                   n-Propylbenzene    6.19        5.78       0.42
#                   n-Propylbenzene    5.84        5.78       0.42
#                   n-Propylbenzene    6.10        5.78       0.42
#                   n-Propylbenzene    5.93        5.78       0.42
#                   n-Propylbenzene    5.86        5.78       0.42
#                   n-Propylbenzene    5.49        5.78       0.42
#                   n-Propylbenzene    3.78        5.78       0.42
#                   n-Propylbenzene    5.71        5.78       0.42
#                   n-Propylbenzene    4.24        5.78       0.42
#          1,1-Dimethylethylbenzene    6.41        6.24       0.85
#          1,1-Dimethylethylbenzene    6.06        6.24       0.85
#        1,2,4,5-Tetramethylbenzene    5.07        4.75       0.80
#        1,2,4,5-Tetramethylbenzene    5.07        4.75       0.80
# 1-Methyl-2-(1-methylethyl)benzene    4.16        5.86       0.62
# 1-Methyl-3-(1-methylethyl)benzene    4.80        5.86       0.62
# 1-Methyl-4-(1-methylethyl)benzene    6.17        5.86       0.62
#                 Methyl Pivalate     NaN      371.74      18.39
#                  Ethyl Pivalate     NaN      451.76      18.01
#                  Ethyl Pivalate     NaN      451.76      18.01
#                Methyl Hexanoate     NaN      444.83      11.77
#                 Ethyl Hexanoate     NaN      524.84      11.16
#         Ethyl 2-Methylbutanoate     NaN      458.31      16.10
#                    Methanethiol     NaN      218.36      20.14
#                    Methanethiol     NaN      218.36      20.14
#                    Methanethiol     NaN      218.36      20.14
#                    Methanethiol     NaN      218.36      20.14
#                     Ethanethiol     NaN      267.00      19.84
#                     Ethanethiol     NaN      267.00      19.84
#                  1-Propanethiol     NaN      330.00      19.89
#                  1-Propanethiol     NaN      330.00      19.89
#                   1-Butanethiol     NaN      393.00      19.93
#                   1-Butanethiol     NaN      393.00      19.93
#                Dimethyl Sulfide     NaN      238.14      13.30
#                Dimethyl Sulfide     NaN      238.14      13.30
#                Dimethyl Sulfide     NaN      238.14      13.30
#                Dimethyl Sulfide     NaN      238.14      13.30
#                 Diethyl Sulfide     NaN      335.43      12.36
#                Dipropyl Sulfide     NaN      461.43      12.51
#              Dimethyl Disulfide     NaN      275.86      15.11
#              Dimethyl Disulfide     NaN      275.86      15.11
#              Dimethyl Disulfide     NaN      275.86      15.11
#               Diethyl Disulfide     NaN      373.14      14.29
#               Diethyl Disulfide     NaN      373.14      14.29
#              Dipropyl Disulfide     NaN      499.15      14.43
#                    Acetonitrile     NaN      145.70       7.44
#                    Acetonitrile     NaN      145.70       7.44
#                    Acetonitrile     NaN      145.70       7.44
#                    Acetonitrile     NaN      145.70       7.44
#                    Acetonitrile     NaN      145.70       7.44
#                    Acetonitrile     NaN      145.70       7.44
#                    Acetonitrile     NaN      145.70       7.44
#                    Acetonitrile     NaN      145.70       7.44
#                    Acetonitrile     NaN      145.70       7.44
#                    Acetonitrile     NaN      145.70       7.44
#                  Propanenitrile     NaN      208.70       7.57
#                  Propanenitrile     NaN      208.70       7.57
#                   Butanenitrile     NaN      271.70       7.70
#                   Butanenitrile     NaN      271.70       7.70
#          2-Methylpropanenitrile     NaN      268.17      14.00
#                  Pentanenitrile     NaN      334.71       7.82
#                 Butanedinitrile     NaN      165.55       9.80
#                Pentanedinitrile     NaN      228.55       9.90
#                Pentanedinitrile     NaN      228.55       9.90
#                 Hexanedinitrile     NaN      291.55      10.00
#            4-Ethenylcyclohexene     NaN      530.92      33.93
#                          Indane     NaN      298.21      21.59
#                        Tetralin     NaN      363.53      21.74
#               2-Cyclohexen-1-ol     NaN      370.00      22.33
#                        Tetralin     NaN      363.53      21.74
#                        1-Hexene     NaN      475.10      16.80
#                        1-Octene     NaN      601.11      16.92
#                    Ethylbenzene     NaN      390.63      16.37
#                  n-Butylbenzene     NaN      516.64      16.48
#                 n-Pentylbenzene     NaN      579.64      16.54
#                  n-Hexylbenzene     NaN      642.64      16.60
#                    Cyclopentene     NaN      319.26      16.65

# %%
# df = pd.read_csv('ORCHYD_properties_and_groups.csv')
# df
